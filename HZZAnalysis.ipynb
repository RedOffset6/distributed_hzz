# %% [markdown]
# <CENTER><img src="../../images/ATLASOD.gif" style="width:50%"></CENTER>

# %% [markdown]
# # How to rediscover the Higgs boson yourself!
# This notebook uses ATLAS Open Data http://opendata.atlas.cern to show you the steps to rediscover the Higgs boson yourself!
#
# ATLAS Open Data provides open access to proton-proton collision data at the LHC for educational purposes. ATLAS Open Data resources are ideal for high-school, undergraduate and postgraduate students.
#
# Notebooks are web applications that allow you to create and share documents that can contain for example:
# 1. live code
# 2. visualisations
# 3. narrative text
#
# The idea is that cuts increase the ratio of signal ($H \rightarrow ZZ \rightarrow \ell\ell\ell\ell$) to background ($Z, t\bar{t}, ZZ \rightarrow \ell\ell\ell\ell$)
#
# First, the amount of $Z$ and $t\bar{t}$ background is reduced, since these are quite different to the signal.
#
# Then, the amount of $ZZ \rightarrow \ell\ell\ell\ell$ is reduced, whilst keeping as much $H \rightarrow ZZ \rightarrow \ell\ell\ell\ell$ signal as possible.
#
# The datasets used in this notebook have already been filtered to include at least 4 leptons per event, so that processing is quicker.
#
# This analysis loosely follows the [discovery of the Higgs boson by ATLAS](https://www.sciencedirect.com/science/article/pii/S037026931200857X) (mostly Section 4 and 4.1)
#
# By the end of this notebook you will be able to:
# 1. rediscover the Higgs boson yourself!
# 2. know some general principles of a particle physics analysis
#
# Feynman diagram pictures are borrowed from our friends at https://www.particlezoo.net

# %% [markdown]
# <CENTER><img src="images/feynman_diagrams/HZZ_feynman.png" style="width:40%"></CENTER>

# %% [markdown]
# <a id='contents'></a>

# %% [markdown]
# Contents:
#
# [Running a Jupyter notebook](#running) <br />
# [First time setup on your computer (no need on mybinder)](#setup_computer) <br />
# [To setup everytime](#setup_everytime) <br />
# [Lumi, fraction, file path](#fraction) <br />
# [Samples](#samples) <br />
# [Changing a cut](#changing_cut) <br />
# [Applying a cut](#applying_cut) <br />
# [Plotting](#plotting) <br />
# [What can you do to explore this analysis?](#going_further) <br />

# %% [markdown]
# <a id='running'></a>

# %% [markdown]
# ## Running a Jupyter notebook
#
# To run the whole Jupyter notebook, in the top menu click Cell -> Run All.
#
# To propagate a change you've made to a piece of code, click Cell -> Run All Below.
#
# You can also run a single code cell, by clicking Cell -> Run Cells, or using the keyboard shortcut Shift+Enter.

# %% [markdown]
# <a id='setup_computer'></a>

# %% [markdown]
# ## First time setup on your computer (no need on mybinder)
# This first cell only needs to be run the first time you open this notebook on your computer.
#
# If you close Jupyter and re-open on the same computer, you won't need to run this first cell again.
#
# If you open on mybinder, you don't need to run this cell.

# %%
import sys
# update the pip package installer
# !{sys.executable} -m pip install --upgrade --user pip
# install required packages
# !{sys.executable} -m pip install --upgrade --user uproot awkward vector numpy matplotlib
# Out:
# Requirement already satisfied: pip in c:\users\benlu\newanaconda3\lib\site-packages (22.2.2)
# Collecting pip
#   Downloading pip-23.3.2-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 8.4 MB/s eta 0:00:00
# Installing collected packages: pip
# Successfully installed pip-23.3.2
#   WARNING: The scripts pip.exe, pip3.11.exe, pip3.9.exe and pip3.exe are installed in 'C:\Users\benlu\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting uproot
#   Downloading uproot-5.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting awkward
#   Downloading awkward-2.5.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting vector
#   Downloading vector-1.1.1.post1-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: numpy in c:\users\benlu\newanaconda3\lib\site-packages (1.26.0)
# Collecting numpy
#   Downloading numpy-1.26.2-cp39-cp39-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 61.2/61.2 kB ? eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\benlu\newanaconda3\lib\site-packages (3.5.2)
# Collecting matplotlib
#   Downloading matplotlib-3.8.2-cp39-cp39-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: fsspec in c:\users\benlu\newanaconda3\lib\site-packages (from uproot) (2022.7.1)
# Requirement already satisfied: packaging in c:\users\benlu\newanaconda3\lib\site-packages (from uproot) (21.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\benlu\newanaconda3\lib\site-packages (from uproot) (4.3.0)
# Collecting awkward-cpp==27 (from awkward)
#   Downloading awkward_cpp-27-cp39-cp39-win_amd64.whl.metadata (2.2 kB)
# Collecting importlib-metadata>=4.13.0 (from awkward)
#   Downloading importlib_metadata-7.0.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.0-cp39-cp39-win_amd64.whl.metadata (5.8 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\benlu\newanaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\benlu\newanaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\benlu\newanaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: pillow>=8 in c:\users\benlu\newanaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\benlu\newanaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\benlu\newanaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Downloading importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\benlu\newanaconda3\lib\site-packages (from importlib-metadata>=4.13.0->awkward) (3.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\benlu\newanaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading uproot-5.2.0-py3-none-any.whl (343 kB)
#    ---------------------------------------- 343.6/343.6 kB 7.1 MB/s eta 0:00:00
# Downloading awkward-2.5.1-py3-none-any.whl (733 kB)
#    ---------------------------------------- 733.1/733.1 kB 9.1 MB/s eta 0:00:00
# Downloading awkward_cpp-27-cp39-cp39-win_amd64.whl (533 kB)
#    --------------------------------------- 533.5/533.5 kB 11.1 MB/s eta 0:00:00
# Downloading vector-1.1.1.post1-py3-none-any.whl (171 kB)
#    --------------------------------------- 171.3/171.3 kB 10.1 MB/s eta 0:00:00
# Downloading numpy-1.26.2-cp39-cp39-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 15.8/15.8 MB 6.5 MB/s eta 0:00:00
# Downloading matplotlib-3.8.2-cp39-cp39-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 7.6/7.6 MB 6.3 MB/s eta 0:00:00
# Downloading contourpy-1.2.0-cp39-cp39-win_amd64.whl (181 kB)
#    ---------------------------------------- 181.9/181.9 kB 5.5 MB/s eta 0:00:00
# Downloading importlib_metadata-7.0.0-py3-none-any.whl (23 kB)
# Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Installing collected packages: numpy, importlib-resources, importlib-metadata, vector, contourpy, awkward-cpp, matplotlib, awkward, uproot
# Successfully installed awkward-2.5.1 awkward-cpp-27 contourpy-1.2.0 importlib-metadata-7.0.0 importlib-resources-6.1.1 matplotlib-3.8.2 numpy-1.26.2 uproot-5.2.0 vector-1.1.1.post1
#   WARNING: The script f2py.exe is installed in 'C:\Users\benlu\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.26.2 which is incompatible.
# scipy 1.9.1 requires numpy<1.25.0,>=1.18.5, but you have numpy 1.26.2 which is incompatible.

# %%
# !pip install aiohttp
# Out:
# Requirement already satisfied: aiohttp in c:\users\benlu\newanaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\benlu\newanaconda3\lib\site-packages (from aiohttp) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\benlu\newanaconda3\lib\site-packages (from aiohttp) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\benlu\newanaconda3\lib\site-packages (from aiohttp) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\benlu\newanaconda3\lib\site-packages (from aiohttp) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\benlu\newanaconda3\lib\site-packages (from aiohttp) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\benlu\newanaconda3\lib\site-packages (from aiohttp) (4.0.3)
# Requirement already satisfied: idna>=2.0 in c:\users\benlu\newanaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp) (3.3)

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# <a id='setup_everytime'></a>

# %% [markdown]
# ## To setup everytime
# Cell -> Run All Below
#
# to be done every time you re-open this notebook
#
# We're going to be using a number of tools to help us:
# * uproot: lets us read .root files typically used in particle physics into data formats used in python
# * awkward: lets us store data as awkward arrays, a format that generalizes numpy to nested data with possibly variable length lists
# * vector: to allow vectorized 4-momentum calculations
# * numpy: provides numerical calculations such as histogramming
# * matplotlib: common tool for making plots, figures, images, visualisations

# %%
import uproot # for reading .root files
import awkward as ak # to represent nested data in columnar format
import vector # for 4-momentum calculations
import time # to measure time to analyse
import math # for mathematical functions such as square root
import numpy as np # for numerical calculations such as histogramming
import matplotlib.pyplot as plt # for plotting
from matplotlib.ticker import AutoMinorLocator # for minor ticks

import infofile # local file containing cross-sections, sums of weights, dataset IDs
# Out:
# C:\Users\benlu\AppData\Roaming\Python\Python39\site-packages\matplotlib\projections\__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# <a id='fraction'></a>

# %% [markdown]
# ## Lumi, fraction, file path
#
# General definitions of fraction of data used, where to access the input files

# %%
#lumi = 0.5 # fb-1 # data_A only
#lumi = 1.9 # fb-1 # data_B only
#lumi = 2.9 # fb-1 # data_C only
#lumi = 4.7 # fb-1 # data_D only
lumi = 10 # fb-1 # data_A,data_B,data_C,data_D

fraction = 0.5 # reduce this is if you want the code to run quicker
                                                                                                                                  
#tuple_path = "Input/4lep/" # local 
tuple_path = "https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/4lep/" # web address

# %% [markdown]
# <a id='samples'></a>

# %% [markdown]
# ## Samples
#
# samples to process

# %%
samples = {

    'data': {
        'list' : ['data_A','data_B','data_C','data_D'],
    },

    r'Background $Z,t\bar{t}$' : { # Z + ttbar
        'list' : ['Zee','Zmumu','ttbar_lep'],
        'color' : "#6b59d3" # purple
    },

    r'Background $ZZ^*$' : { # ZZ
        'list' : ['llll'],
        'color' : "#ff0000" # red
    },

    r'Signal ($m_H$ = 125 GeV)' : { # H -> ZZ -> llll
        'list' : ['ggH125_ZZ4lep','VBFH125_ZZ4lep','WH125_ZZ4lep','ZH125_ZZ4lep'],
        'color' : "#00cdff" # light blue
    },

}

# %% [markdown]
# Units, as stored in the data files

# %%
MeV = 0.001
GeV = 1.0

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# Define function to get data from files.
#
# The datasets used in this notebook have already been filtered to include at least 4 leptons per event, so that processing is quicker.

# %%
def get_data_from_files():
    data = {} # define empty dictionary to hold awkward arrays
    for s in samples: # loop over samples
        
        print(f"s = {s}")
        
        print('Processing '+s+' samples') # print which sample
        frames = [] # define empty list to hold data
        for val in samples[s]['list']: # loop over each file
            
            print(f"val = {val}")
            
            if s == 'data': prefix = "Data/" # Data prefix
            else: # MC prefix
                prefix = "MC/mc_"+str(infofile.infos[val]["DSID"])+"."
            fileString = tuple_path+prefix+val+".4lep.root" # file name to open
            temp = read_file(fileString,val) # call the function read_file defined below
            frames.append(temp) # append array returned from read_file to list of awkward arrays
        data[s] = ak.concatenate(frames) # dictionary entry is concatenated awkward arrays
    
    return data # return dictionary of awkward arrays

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# define function to calculate weight of MC event

# %%
def calc_weight(xsec_weight, events):
    return (
        xsec_weight
        * events.mcWeight
        * events.scaleFactor_PILEUP
        * events.scaleFactor_ELE
        * events.scaleFactor_MUON 
        * events.scaleFactor_LepTRIGGER
    )

# %% [markdown]
# define function to get cross-section weight

# %%
def get_xsec_weight(sample):
    info = infofile.infos[sample] # open infofile
    xsec_weight = (lumi*1000*info["xsec"])/(info["sumw"]*info["red_eff"]) #*1000 to go from fb-1 to pb-1
    return xsec_weight # return cross-section weight

# %% [markdown]
# define function to calculate 4-lepton invariant mass.
#
# Note: `lep_(pt|eta|phi|E)` are variable length lists of lepton momentum components for each event, represented by awkward arrays.

# %%
def calc_mllll(lep_pt, lep_eta, lep_phi, lep_E):
    # construct awkward 4-vector array
    p4 = vector.zip({"pt": lep_pt, "eta": lep_eta, "phi": lep_phi, "E": lep_E})
    # calculate invariant mass of first 4 leptons
    # [:, i] selects the i-th lepton in each event
    # .M calculates the invariant mass
    return (p4[:, 0] + p4[:, 1] + p4[:, 2] + p4[:, 3]).M * MeV

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# <a id='changing_cut'></a>

# %% [markdown]
# ## Changing a cut
#
# If you change a cut: Cell -> Run All Below
#
# If you change a cut here, you also need to make sure the cut is applied in the "[Applying a cut](#applying_cut)" cell.

# %%
# cut on lepton charge
# paper: "selecting two pairs of isolated leptons, each of which is comprised of two leptons with the same flavour and opposite charge"
def cut_lep_charge(lep_charge):
# throw away when sum of lepton charges is not equal to 0
# first lepton in each event is [:, 0], 2nd lepton is [:, 1] etc
    return lep_charge[:, 0] + lep_charge[:, 1] + lep_charge[:, 2] + lep_charge[:, 3] != 0

# cut on lepton type
# paper: "selecting two pairs of isolated leptons, each of which is comprised of two leptons with the same flavour and opposite charge"
def cut_lep_type(lep_type):
# for an electron lep_type is 11
# for a muon lep_type is 13
# throw away when none of eeee, mumumumu, eemumu
    sum_lep_type = lep_type[:, 0] + lep_type[:, 1] + lep_type[:, 2] + lep_type[:, 3]
    return (sum_lep_type != 44) & (sum_lep_type != 48) & (sum_lep_type != 52)

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# <a id='applying_cut'></a>

# %% [markdown]
# ## Applying a cut
# If you add a cut: Cell -> Run All Below

# %%
def read_file(path,sample):
    start = time.time() # start the clock
    print("\tProcessing: "+sample) # print which sample is being processed
    data_all = [] # define empty list to hold all data for this sample
    
    print(path)
    
    # open the tree called mini using a context manager (will automatically close files/resources)
    with uproot.open(path + ":mini") as tree:
        numevents = tree.num_entries # number of events
        if 'data' not in sample: xsec_weight = get_xsec_weight(sample) # get cross-section weight
        for data in tree.iterate(['lep_pt','lep_eta','lep_phi',
                                  'lep_E','lep_charge','lep_type', 
                                  # add more variables here if you make cuts on them 
                                  'mcWeight','scaleFactor_PILEUP',
                                  'scaleFactor_ELE','scaleFactor_MUON',
                                  'scaleFactor_LepTRIGGER'], # variables to calculate Monte Carlo weight
                                 library="ak", # choose output type as awkward array
                                 entry_stop=numevents*fraction): # process up to numevents*fraction
            
            print(data)
            
            nIn = len(data) # number of events in this batch

            if 'data' not in sample: # only do this for Monte Carlo simulation files
                # multiply all Monte Carlo weights and scale factors together to give total weight
                data['totalWeight'] = calc_weight(xsec_weight, data)

            # cut on lepton charge using the function cut_lep_charge defined above
            data = data[~cut_lep_charge(data.lep_charge)]

            # cut on lepton type using the function cut_lep_type defined above
            data = data[~cut_lep_type(data.lep_type)]

            # calculation of 4-lepton invariant mass using the function calc_mllll defined above
            data['mllll'] = calc_mllll(data.lep_pt, data.lep_eta, data.lep_phi, data.lep_E)

            # array contents can be printed at any stage like this
            #print(data)

            # array column can be printed at any stage like this
            #print(data['lep_pt'])

            # multiple array columns can be printed at any stage like this
            #print(data[['lep_pt','lep_eta']])

            nOut = len(data) # number of events passing cuts in this batch
            data_all.append(data) # append array from this batch
            elapsed = time.time() - start # time taken to process
            print("\t\t nIn: "+str(nIn)+",\t nOut: \t"+str(nOut)+"\t in "+str(round(elapsed,1))+"s") # events before and after
    
    return ak.concatenate(data_all) # return array containing events passing all cuts

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# This is where the processing happens

# %%
start = time.time() # time at start of whole processing
data = get_data_from_files() # process all files
elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# s = data
# Processing data samples
# val = data_A
# 	Processing: data_A
# https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/4lep/Data/data_A.4lep.root
# [{lep_pt: [4.91e+04, ..., 2.74e+04], lep_eta: [-1.66, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 0.8s
# [{lep_pt: [1.76e+05, ..., 7.98e+04], lep_eta: [2.08, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 0.9s
# [{lep_pt: [6.53e+04, ..., 8.8e+03], lep_eta: [0.103, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.0s
# [{lep_pt: [7.46e+04, ..., 1.02e+04], lep_eta: [-1.56, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.1s
# [{lep_pt: [1.47e+05, ..., 2.98e+04], lep_eta: [-0.201, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.2s
# [{lep_pt: [1.36e+05, ..., 4.26e+04], lep_eta: [1.49, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# [{lep_pt: [4.2e+04, ..., 7.9e+03], lep_eta: [-1.88, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.5s
# [{lep_pt: [6.77e+04, ..., 1.03e+04], lep_eta: [-1.53, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# [{lep_pt: [1.34e+05, ..., 9.53e+04], lep_eta: [-0.353, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.7s
# [{lep_pt: [4.9e+04, ..., 9.64e+03], lep_eta: [-1.26, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# [{lep_pt: [5.59e+04, ..., 7.21e+03], lep_eta: [-1.7, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.9s
# [{lep_pt: [3.95e+04, ..., 1.17e+04], lep_eta: [-0.677, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.0s
# [{lep_pt: [5.81e+04, ..., 8.71e+03], lep_eta: [1.7, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.2s
# [{lep_pt: [3.81e+04, ..., 7.78e+03], lep_eta: [-1.62, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.3s
# [{lep_pt: [8.05e+04, ..., 8.56e+03], lep_eta: [0.158, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# [{lep_pt: [4.89e+04, ..., 2.12e+04], lep_eta: [1.96, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# [{lep_pt: [6.71e+04, ..., 1.16e+04], lep_eta: [1.24, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# [{lep_pt: [5.99e+04, ..., 3.5e+04], lep_eta: [-1.98, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# [{lep_pt: [5.12e+04, ..., 8.63e+03], lep_eta: [-1.29, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# val = data_B
# 	Processing: data_B
# https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/4lep/Data/data_B.4lep.root
# [{lep_pt: [4.9e+04, ..., 3.44e+04], lep_eta: [-0.882, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 0.5s
# [{lep_pt: [2.83e+04, ..., 7.98e+03], lep_eta: [2.38, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 0.6s
# [{lep_pt: [5.27e+04, ..., 2.89e+04], lep_eta: [2.25, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 0.7s
# [{lep_pt: [1.88e+05, ..., 1.14e+04], lep_eta: [0.631, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 0.8s
# [{lep_pt: [7.31e+04, ..., 2.88e+04], lep_eta: [0.068, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 0.9s
# [{lep_pt: [4.56e+04, ..., 1.17e+04], lep_eta: [0.992, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.1s
# [{lep_pt: [6.54e+04, ..., 1.16e+04], lep_eta: [-0.834, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.2s
# [{lep_pt: [6.38e+04, ..., 1.04e+04], lep_eta: [0.295, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# [{lep_pt: [2.9e+04, ..., 7.02e+03], lep_eta: [0.357, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.4s
# [{lep_pt: [9.98e+04, ..., 1.03e+04], lep_eta: [-0.122, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# [{lep_pt: [3.54e+04, ..., 7.31e+03], lep_eta: [2.11, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# [{lep_pt: [4.76e+04, ..., 1.62e+04], lep_eta: [-0.0593, ...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.7s
# [{lep_pt: [8.04e+04, ..., 1.44e+04], lep_eta: [-1.91, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# [{lep_pt: [5.07e+04, ..., 8.08e+03], lep_eta: [2.09, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.9s
# [{lep_pt: [1.77e+05, ..., 1.1e+04], lep_eta: [0.083, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.0s
# [{lep_pt: [5.34e+04, ..., 7.2e+03], lep_eta: [2, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.2s
# [{lep_pt: [4.12e+04, ..., 1.37e+04], lep_eta: [2.02, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.3s
# [{lep_pt: [6e+04, 3.7e+04, ..., 8.46e+03], lep_eta: [...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# [{lep_pt: [5e+04, 4.91e+04, ..., 1.5e+04], lep_eta: [1.63, ...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# [{lep_pt: [4.89e+04, ..., 2.92e+04], lep_eta: [0.954, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.6s
# [{lep_pt: [1.07e+05, ..., 1.65e+04], lep_eta: [2.35, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# [{lep_pt: [8.07e+04, ..., 7.02e+03], lep_eta: [-1.14, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.9s
# [{lep_pt: [7.45e+04, ..., 7.39e+03], lep_eta: [0.354, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.0s
# [{lep_pt: [8.2e+04, ..., 3.49e+04], lep_eta: [0.213, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# [{lep_pt: [9.76e+04, ..., 1.76e+04], lep_eta: [-1.18, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 3.2s
# [{lep_pt: [8.14e+04, ..., 7.09e+03], lep_eta: [0.954, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.3s
# [{lep_pt: [7.28e+04, ..., 7.01e+03], lep_eta: [-0.92, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.4s
# [{lep_pt: [5.47e+04, ..., 2.99e+04], lep_eta: [1.22, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 3.6s
# [{lep_pt: [4.24e+04, ..., 7.37e+03], lep_eta: [1.93, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 3.7s
# [{lep_pt: [3.64e+04, ..., 7.39e+03], lep_eta: [-2.33, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.8s
# [{lep_pt: [4.69e+04, ..., 1.17e+04], lep_eta: [-2.24, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 3.9s
# [{lep_pt: [5.18e+04, ..., 2.22e+04], lep_eta: [-1.61, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.0s
# [{lep_pt: [9.16e+04, ..., 7.68e+03], lep_eta: [-0.522, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 4.1s
# [{lep_pt: [6.09e+04, ..., 8.37e+03], lep_eta: [-1.39, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.3s
# [{lep_pt: [5.82e+04, ..., 7.57e+03], lep_eta: [-0.288, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.4s
# [{lep_pt: [9.46e+04, ..., 2.43e+04], lep_eta: [1.21, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.5s
# [{lep_pt: [5.35e+04, ..., 3.56e+04], lep_eta: [0.949, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.6s
# [{lep_pt: [5.35e+04, ..., 3.06e+04], lep_eta: [0.223, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 4.7s
# [{lep_pt: [4.09e+04, ..., 7.33e+03], lep_eta: [-1.86, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 4.8s
# [{lep_pt: [6.39e+04, ..., 1.34e+04], lep_eta: [-0.387, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.9s
# [{lep_pt: [7.01e+04, ..., 1.15e+04], lep_eta: [-0.284, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.0s
# [{lep_pt: [2.95e+04, ..., 1.06e+04], lep_eta: [2.43, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.1s
# [{lep_pt: [3.72e+04, ..., 7.52e+03], lep_eta: [-0.685, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 5.2s
# [{lep_pt: [1.36e+05, ..., 1.12e+04], lep_eta: [1.37, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.3s
# [{lep_pt: [5.66e+04, ..., 7.71e+03], lep_eta: [-0.794, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 5.3s
# [{lep_pt: [4.27e+04, ..., 9.01e+03], lep_eta: [0.863, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.4s
# [{lep_pt: [6.15e+04, ..., 8.56e+03], lep_eta: [-0.0821, ...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 5.5s
# [{lep_pt: [5.1e+04, ..., 7.39e+03], lep_eta: [-0.598, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.7s
# [{lep_pt: [5.39e+04, ..., 7.95e+03], lep_eta: [2.16, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 5.8s
# [{lep_pt: [1.13e+05, ..., 2.4e+04], lep_eta: [-2.46, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.9s
# [{lep_pt: [3.75e+04, ..., 1.22e+04], lep_eta: [-0.267, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 6.0s
# [{lep_pt: [4.36e+04, ..., 7.25e+03], lep_eta: [-0.346, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 6.1s
# [{lep_pt: [5.76e+04, ..., 8.03e+03], lep_eta: [0.853, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 6.2s
# [{lep_pt: [7.78e+04, ..., 1.68e+04], lep_eta: [1.48, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 6.3s
# [{lep_pt: [5.93e+04, ..., 7.1e+03], lep_eta: [2.46, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 6.4s
# [{lep_pt: [6.96e+04, ..., 1.85e+04], lep_eta: [0.0729, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 6.5s
# [{lep_pt: [5.11e+04, ..., 7.33e+03], lep_eta: [-0.83, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 6.6s
# [{lep_pt: [6.32e+04, ..., 7.49e+03], lep_eta: [-1.16, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 6.7s
# [{lep_pt: [3.33e+04, ..., 7.48e+03], lep_eta: [-0.472, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 6.8s
# [{lep_pt: [4.92e+04, ..., 7.09e+03], lep_eta: [1.23, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 6.9s
# [{lep_pt: [9.42e+04, ..., 7.37e+03], lep_eta: [-1.23, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.0s
# [{lep_pt: [5.08e+04, ..., 8.55e+03], lep_eta: [1.99, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 7.1s
# [{lep_pt: [7.32e+04, ..., 2.72e+04], lep_eta: [0.622, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.3s
# [{lep_pt: [4.57e+04, ..., 7.09e+03], lep_eta: [2.07, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.4s
# [{lep_pt: [5.25e+04, ..., 1.98e+04], lep_eta: [1.23, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.5s
# [{lep_pt: [1.78e+05, ..., 7.57e+03], lep_eta: [0.0615, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 7.6s
# [{lep_pt: [5.72e+04, ..., 3.81e+04], lep_eta: [0.0166, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.7s
# [{lep_pt: [1.29e+05, ..., 2.27e+04], lep_eta: [0.564, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.9s
# [{lep_pt: [1.53e+05, ..., 1.1e+04], lep_eta: [-0.653, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.0s
# [{lep_pt: [8.36e+04, ..., 2.78e+04], lep_eta: [0.437, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.1s
# [{lep_pt: [5.13e+04, ..., 8.9e+03], lep_eta: [2.39, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 8.2s
# [{lep_pt: [5e+04, 3.89e+04, ..., 8.95e+03], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 8.3s
# [{lep_pt: [6.12e+04, ..., 2.74e+04], lep_eta: [0.743, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.4s
# [{lep_pt: [4.78e+04, ..., 7.09e+03], lep_eta: [1.35, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.5s
# [{lep_pt: [4.13e+04, ..., 2.91e+04], lep_eta: [1.09, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.7s
# [{lep_pt: [1.75e+05, ..., 3.32e+04], lep_eta: [0.264, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.8s
# [{lep_pt: [5.51e+04, ..., 4.01e+04], lep_eta: [1.16, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.9s
# [{lep_pt: [7.77e+04, ..., 3.64e+04], lep_eta: [-0.0654, ...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 9.0s
# val = data_C
# 	Processing: data_C
# https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/4lep/Data/data_C.4lep.root
# [{lep_pt: [4.16e+04, ..., 1.23e+04], lep_eta: [0.996, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 0.7s
# [{lep_pt: [1.25e+05, ..., 2.4e+04], lep_eta: [-0.857, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 0.8s
# [{lep_pt: [4.8e+04, ..., 7.37e+03], lep_eta: [0.0912, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 0.9s
# [{lep_pt: [1.05e+05, ..., 3.32e+04], lep_eta: [-1.3, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.1s
# [{lep_pt: [8.13e+04, ..., 7.75e+03], lep_eta: [-1.59, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.2s
# [{lep_pt: [5.83e+04, ..., 3.2e+04], lep_eta: [-1.39, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# [{lep_pt: [6.21e+04, ..., 3.05e+04], lep_eta: [0.656, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# [{lep_pt: [3.97e+04, 3.28e+04, ..., 7e+03], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.6s
# [{lep_pt: [4.41e+04, ..., 1.36e+04], lep_eta: [-0.345, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.7s
# [{lep_pt: [1.38e+05, ..., 7.4e+03], lep_eta: [-0.542, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.8s
# [{lep_pt: [1.13e+05, ..., 2.93e+04], lep_eta: [-1.65, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# [{lep_pt: [2.65e+04, ..., 7.62e+03], lep_eta: [1.88, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.1s
# [{lep_pt: [4.5e+04, ..., 7.71e+03], lep_eta: [-1.02, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.2s
# [{lep_pt: [4.4e+04, ..., 7.47e+03], lep_eta: [-1.59, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.3s
# [{lep_pt: [5.93e+04, ..., 2.28e+04], lep_eta: [-0.166, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# [{lep_pt: [4.69e+04, ..., 7.06e+03], lep_eta: [1.76, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# [{lep_pt: [4.37e+04, ..., 9.07e+03], lep_eta: [-1.03, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# [{lep_pt: [6.63e+04, ..., 7.89e+03], lep_eta: [0.698, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.8s
# [{lep_pt: [4.96e+04, ..., 8.19e+03], lep_eta: [-2.18, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.9s
# [{lep_pt: [2.76e+04, ..., 1.31e+04], lep_eta: [0.106, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.0s
# [{lep_pt: [1.09e+05, ..., 1.9e+04], lep_eta: [-2.55, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# [{lep_pt: [1.02e+05, ..., 1.58e+04], lep_eta: [1.15, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.2s
# [{lep_pt: [3.21e+04, ..., 1.09e+04], lep_eta: [-1.7, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 3.4s
# [{lep_pt: [1.16e+05, ..., 9.02e+03], lep_eta: [0.682, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.5s
# [{lep_pt: [3e+04, 2.06e+04, ..., 7.57e+03], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.6s
# [{lep_pt: [3.37e+04, ..., 8.07e+03], lep_eta: [-0.364, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.7s
# [{lep_pt: [5.82e+04, ..., 3.36e+04], lep_eta: [-1.22, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 3.8s
# [{lep_pt: [4.18e+04, ..., 1.14e+04], lep_eta: [0.95, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.9s
# [{lep_pt: [6.66e+04, ..., 7.24e+03], lep_eta: [1.98, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 4.0s
# [{lep_pt: [6.3e+04, ..., 2.87e+04], lep_eta: [-1.59, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.1s
# [{lep_pt: [4.69e+04, ..., 7.23e+03], lep_eta: [0.603, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 4.2s
# [{lep_pt: [4.64e+04, ..., 7.03e+03], lep_eta: [-0.502, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 4.3s
# [{lep_pt: [2.92e+04, ..., 8.06e+03], lep_eta: [-0.702, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.4s
# [{lep_pt: [1.51e+05, ..., 3.28e+04], lep_eta: [-0.395, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 4.6s
# [{lep_pt: [1.26e+05, ..., 2.07e+04], lep_eta: [1.39, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.7s
# [{lep_pt: [7.7e+04, ..., 2.75e+04], lep_eta: [1.04, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.8s
# [{lep_pt: [6.24e+04, ..., 2.5e+04], lep_eta: [0.441, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 4.9s
# [{lep_pt: [4.14e+04, ..., 1.07e+04], lep_eta: [1.57, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 5.0s
# [{lep_pt: [6.54e+04, ..., 1.67e+04], lep_eta: [1.01, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.1s
# [{lep_pt: [3.67e+04, ..., 1.67e+04], lep_eta: [0.542, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.3s
# [{lep_pt: [9.45e+04, 2.43e+04, ..., 7e+03], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.4s
# [{lep_pt: [4.47e+04, ..., 7.72e+03], lep_eta: [-0.263, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 5.5s
# [{lep_pt: [7.58e+04, ..., 7.52e+03], lep_eta: [0.538, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.6s
# [{lep_pt: [1.06e+05, ..., 1.34e+04], lep_eta: [0.117, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.7s
# [{lep_pt: [4.93e+04, 2.44e+04, ..., 1e+04], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 5.8s
# [{lep_pt: [8.24e+04, ..., 3.01e+04], lep_eta: [0.0403, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.9s
# [{lep_pt: [7.09e+04, ..., 1.12e+04], lep_eta: [-0.0911, ...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 6.0s
# [{lep_pt: [7.72e+04, ..., 8.28e+03], lep_eta: [1.72, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 6.1s
# [{lep_pt: [2.95e+04, ..., 1.15e+04], lep_eta: [-0.782, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 6.2s
# [{lep_pt: [8.66e+04, ..., 2.06e+04], lep_eta: [-2.19, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 6.4s
# [{lep_pt: [1.22e+05, ..., 5.34e+04], lep_eta: [-0.151, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 6.5s
# [{lep_pt: [6.52e+04, ..., 9.37e+03], lep_eta: [-0.217, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 6.6s
# [{lep_pt: [3.03e+04, 2.91e+04, ..., 1e+04], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 6.7s
# [{lep_pt: [4.42e+04, ..., 7.04e+03], lep_eta: [1.41, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 6.8s
# [{lep_pt: [3.1e+04, ..., 9.18e+03], lep_eta: [-0.0939, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 6.9s
# [{lep_pt: [2.9e+04, ..., 1.34e+04], lep_eta: [0.87, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 7.0s
# [{lep_pt: [5.59e+04, ..., 7.34e+03], lep_eta: [-0.697, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.2s
# [{lep_pt: [7.5e+04, ..., 2.39e+04], lep_eta: [0.462, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.3s
# [{lep_pt: [5.74e+04, ..., 3.39e+04], lep_eta: [-1.16, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.4s
# [{lep_pt: [1.01e+05, ..., 1.91e+04], lep_eta: [1.33, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.5s
# [{lep_pt: [5.76e+04, ..., 2.37e+04], lep_eta: [2.37, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.6s
# [{lep_pt: [5.56e+04, ..., 8.24e+03], lep_eta: [1.06, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.7s
# [{lep_pt: [1.38e+05, ..., 1.65e+04], lep_eta: [0.212, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.8s
# [{lep_pt: [8.53e+04, ..., 7.14e+03], lep_eta: [1.63, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.0s
# [{lep_pt: [9.41e+04, ..., 1.88e+04], lep_eta: [-1.54, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.1s
# [{lep_pt: [3.8e+04, ..., 7.52e+03], lep_eta: [-0.426, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 8.2s
# [{lep_pt: [3.75e+04, ..., 7.33e+03], lep_eta: [0.713, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 8.3s
# [{lep_pt: [6.11e+04, ..., 1.42e+04], lep_eta: [-0.856, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 8.5s
# [{lep_pt: [2.72e+05, ..., 2.35e+04], lep_eta: [0.982, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 8.6s
# [{lep_pt: [7.23e+04, ..., 2.41e+04], lep_eta: [1.37, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.7s
# [{lep_pt: [1.01e+05, ..., 2.2e+04], lep_eta: [0.515, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.8s
# [{lep_pt: [6.33e+04, ..., 1.13e+04], lep_eta: [-0.526, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 9.0s
# [{lep_pt: [5.58e+04, ..., 2.97e+04], lep_eta: [0.394, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 9.1s
# [{lep_pt: [5.3e+04, ..., 1.18e+04], lep_eta: [-0.809, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 9.2s
# [{lep_pt: [6.74e+04, ..., 2.69e+04], lep_eta: [0.599, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 9.3s
# [{lep_pt: [9.86e+04, ..., 2.94e+04], lep_eta: [0.272, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 9.4s
# [{lep_pt: [5.52e+04, ..., 9.2e+03], lep_eta: [-1.12, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 9.5s
# [{lep_pt: [6.38e+04, 6.24e+04, ..., 2e+04], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 9.7s
# [{lep_pt: [1.02e+05, ..., 7.58e+03], lep_eta: [0.899, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 9.8s
# [{lep_pt: [4.09e+04, ..., 8.54e+03], lep_eta: [0.929, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 9.9s
# [{lep_pt: [4.95e+04, ..., 8.52e+03], lep_eta: [1.49, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 10.0s
# [{lep_pt: [1.22e+05, ..., 1.88e+04], lep_eta: [1.07, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 10.1s
# [{lep_pt: [5.27e+04, ..., 3.16e+04], lep_eta: [-0.188, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 10.2s
# [{lep_pt: [8.09e+04, ..., 9.18e+03], lep_eta: [0.461, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 10.3s
# [{lep_pt: [4.72e+04, ..., 8.6e+03], lep_eta: [-2.05, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 10.4s
# [{lep_pt: [3.15e+04, ..., 7.95e+03], lep_eta: [-2.14, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 10.5s
# [{lep_pt: [8.87e+04, ..., 2.27e+04], lep_eta: [-0.781, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 10.6s
# [{lep_pt: [5.33e+04, ..., 9.57e+03], lep_eta: [0.585, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 10.7s
# [{lep_pt: [6.52e+04, ..., 1.92e+04], lep_eta: [0.0851, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 10.9s
# [{lep_pt: [9.86e+04, ..., 7.35e+03], lep_eta: [0.0962, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 11.0s
# [{lep_pt: [9.02e+04, ..., 2.61e+04], lep_eta: [-0.159, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 11.1s
# [{lep_pt: [4.87e+04, ..., 7.12e+03], lep_eta: [-1.9, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 11.2s
# [{lep_pt: [1.11e+05, ..., 1.28e+04], lep_eta: [2.03, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 11.3s
# [{lep_pt: [4.24e+04, ..., 8.11e+03], lep_eta: [1.01, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 11.4s
# [{lep_pt: [1.33e+05, ..., 1.34e+04], lep_eta: [-2.09, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 11.5s
# [{lep_pt: [6.38e+04, 4e+04, ..., 3.15e+04], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 11.6s
# [{lep_pt: [1.82e+05, ..., 8.95e+03], lep_eta: [0.288, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 11.7s
# [{lep_pt: [3.22e+04, ..., 1.02e+04], lep_eta: [-0.537, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 11.8s
# [{lep_pt: [6.15e+04, 5.44e+04, ..., 1e+04], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 11.9s
# [{lep_pt: [3.92e+04, ..., 1.41e+04], lep_eta: [-0.871, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 12.0s
# [{lep_pt: [2.79e+04, ..., 8.46e+03], lep_eta: [1.29, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 12.1s
# [{lep_pt: [5.01e+04, ..., 8.94e+03], lep_eta: [-0.339, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 12.2s
# [{lep_pt: [5.13e+04, ..., 8.9e+03], lep_eta: [1.72, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 12.4s
# [{lep_pt: [3.95e+04, ..., 7.97e+03], lep_eta: [-1.25, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 12.4s
# [{lep_pt: [3.23e+05, ..., 1.03e+04], lep_eta: [1.56, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 12.5s
# [{lep_pt: [6.27e+04, ..., 1.05e+04], lep_eta: [0.484, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 12.6s
# [{lep_pt: [3.65e+04, ..., 7.59e+03], lep_eta: [1.53, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 12.7s
# [{lep_pt: [9.8e+04, ..., 2.84e+04], lep_eta: [0.036, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 12.8s
# [{lep_pt: [3.57e+04, 2e+04, ..., 8.08e+03], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 13.0s
# [{lep_pt: [3.74e+04, ..., 7.83e+03], lep_eta: [0.97, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 13.1s
# [{lep_pt: [3.08e+05, ..., 1.56e+04], lep_eta: [-1.33, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 13.2s
# [{lep_pt: [9.66e+04, ..., 2.38e+04], lep_eta: [0.603, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 13.3s
# [{lep_pt: [5.21e+04, ..., 1.43e+04], lep_eta: [1.71, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 13.4s
# [{lep_pt: [1.48e+05, ..., 7.65e+03], lep_eta: [-1.81, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 13.5s
# [{lep_pt: [4.13e+04, ..., 7.49e+03], lep_eta: [0.84, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 13.6s
# [{lep_pt: [5.37e+04, ..., 1.11e+04], lep_eta: [-0.0996, ...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 13.7s
# [{lep_pt: [6.94e+04, ..., 8.25e+03], lep_eta: [-1.96, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 13.8s
# [{lep_pt: [1.07e+05, ..., 9.09e+03], lep_eta: [1.53, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 14.0s
# val = data_D
# 	Processing: data_D
# https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/4lep/Data/data_D.4lep.root
# [{lep_pt: [1.74e+05, ..., 4.37e+04], lep_eta: [-0.0839, ...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 0.5s
# [{lep_pt: [5.23e+04, ..., 3.1e+04], lep_eta: [0.0418, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 0.6s
# [{lep_pt: [4.88e+04, ..., 8.09e+03], lep_eta: [0.196, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 0.8s
# [{lep_pt: [1.07e+05, ..., 4.25e+04], lep_eta: [0.0428, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 0.9s
# [{lep_pt: [5.86e+04, ..., 7.41e+03], lep_eta: [-2.09, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.0s
# [{lep_pt: [4.39e+04, ..., 1.07e+04], lep_eta: [0.297, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.1s
# [{lep_pt: [6.03e+04, ..., 1.09e+04], lep_eta: [0.161, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.2s
# [{lep_pt: [4.88e+04, ..., 2.38e+04], lep_eta: [0.077, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.3s
# [{lep_pt: [5.35e+04, ..., 1.01e+04], lep_eta: [0.194, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.4s
# [{lep_pt: [5.39e+04, ..., 1.79e+04], lep_eta: [-0.732, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# [{lep_pt: [2.05e+05, ..., 7.04e+03], lep_eta: [-0.0127, ...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.7s
# [{lep_pt: [1.41e+05, ..., 2.43e+04], lep_eta: [1.76, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# [{lep_pt: [3.57e+04, ..., 9.35e+03], lep_eta: [-2.03, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.9s
# [{lep_pt: [7.65e+04, ..., 1.22e+04], lep_eta: [2.35, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# [{lep_pt: [8.96e+04, ..., 2.86e+04], lep_eta: [-0.99, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# [{lep_pt: [1.35e+05, ..., 9.13e+03], lep_eta: [-0.569, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.2s
# [{lep_pt: [8.41e+04, ..., 1.54e+04], lep_eta: [1.18, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.3s
# [{lep_pt: [1.38e+05, ..., 5.79e+04], lep_eta: [0.867, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# [{lep_pt: [9.26e+04, ..., 2.05e+04], lep_eta: [-0.266, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# [{lep_pt: [4.72e+04, ..., 7.28e+03], lep_eta: [0.613, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.6s
# [{lep_pt: [9.26e+04, ..., 2.14e+04], lep_eta: [-0.0267, ...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# [{lep_pt: [1.02e+06, ..., 7.65e+03], lep_eta: [-0.0414, ...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.8s
# [{lep_pt: [8.01e+04, ..., 8.51e+03], lep_eta: [0.455, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 3.0s
# [{lep_pt: [4.79e+04, ..., 7.14e+03], lep_eta: [0.375, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.1s
# [{lep_pt: [4.92e+04, ..., 8.19e+03], lep_eta: [1.05, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 3.2s
# [{lep_pt: [5.38e+04, ..., 9.54e+03], lep_eta: [2.3, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.3s
# [{lep_pt: [7.04e+04, 2.64e+04, ..., 8e+03], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.4s
# [{lep_pt: [1.06e+05, ..., 4.26e+04], lep_eta: [0.892, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 3.5s
# [{lep_pt: [1.23e+05, ..., 9.31e+03], lep_eta: [0.318, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.6s
# [{lep_pt: [7.88e+04, ..., 2.49e+04], lep_eta: [0.26, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 3.7s
# [{lep_pt: [4.4e+04, ..., 8.95e+03], lep_eta: [2.3, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 3.8s
# [{lep_pt: [6.06e+04, ..., 2.09e+04], lep_eta: [2.35, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 3.9s
# [{lep_pt: [8.46e+04, ..., 1.28e+04], lep_eta: [-0.359, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 4.0s
# [{lep_pt: [4.66e+04, ..., 3.15e+04], lep_eta: [-0.959, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.2s
# [{lep_pt: [5.4e+04, ..., 2.62e+04], lep_eta: [1.31, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.3s
# [{lep_pt: [1.56e+05, ..., 1.19e+04], lep_eta: [1.29, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.4s
# [{lep_pt: [5.45e+04, ..., 2.85e+04], lep_eta: [-0.216, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.5s
# [{lep_pt: [1.41e+05, ..., 3.31e+04], lep_eta: [-0.994, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.6s
# [{lep_pt: [5.83e+04, ..., 1.23e+04], lep_eta: [0.715, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 4.8s
# [{lep_pt: [2.76e+04, ..., 8.09e+03], lep_eta: [1.22, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 4.9s
# [{lep_pt: [9.14e+04, ..., 8.33e+03], lep_eta: [-2.33, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 5.0s
# [{lep_pt: [2.23e+05, ..., 8.43e+03], lep_eta: [1.97, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 5.1s
# [{lep_pt: [4.27e+04, ..., 7.1e+03], lep_eta: [0.778, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.2s
# [{lep_pt: [3.67e+04, ..., 1.12e+04], lep_eta: [-1.94, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.3s
# [{lep_pt: [1.14e+05, ..., 1.93e+04], lep_eta: [-0.396, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.4s
# [{lep_pt: [1.18e+05, ..., 1.98e+04], lep_eta: [0.0589, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.5s
# [{lep_pt: [6.58e+04, ..., 1.01e+04], lep_eta: [-0.371, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.6s
# [{lep_pt: [4.65e+04, ..., 8.58e+03], lep_eta: [0.299, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.7s
# [{lep_pt: [8.84e+04, ..., 1.8e+04], lep_eta: [2.58, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.8s
# [{lep_pt: [5.25e+04, ..., 3.1e+04], lep_eta: [-0.375, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 5.9s
# [{lep_pt: [3.09e+04, ..., 8.65e+03], lep_eta: [-1.19, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 6.1s
# [{lep_pt: [4.83e+04, ..., 9.28e+03], lep_eta: [1.59, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 6.2s
# [{lep_pt: [2e+05, 1.17e+05, ..., 3.34e+04], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 6.3s
# [{lep_pt: [5.35e+04, ..., 8.97e+03], lep_eta: [-0.594, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 6.4s
# [{lep_pt: [4.34e+04, ..., 1.45e+04], lep_eta: [-0.149, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 6.6s
# [{lep_pt: [5.79e+04, ..., 7.4e+03], lep_eta: [-0.969, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 6.7s
# [{lep_pt: [1.01e+05, ..., 1.46e+04], lep_eta: [2.15, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 6.8s
# [{lep_pt: [6.47e+04, ..., 8.01e+03], lep_eta: [2.16, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.0s
# [{lep_pt: [4.54e+04, ..., 1.69e+04], lep_eta: [-0.177, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.2s
# [{lep_pt: [1.4e+05, ..., 9.18e+03], lep_eta: [-0.721, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.3s
# [{lep_pt: [7.61e+04, ..., 1.57e+04], lep_eta: [0.391, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 7.5s
# [{lep_pt: [4.88e+04, ..., 9.36e+03], lep_eta: [-1.08, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.6s
# [{lep_pt: [1.39e+05, ..., 7.11e+03], lep_eta: [-1.72, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 7.7s
# [{lep_pt: [4.46e+04, ..., 1.35e+04], lep_eta: [-0.342, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 7.8s
# [{lep_pt: [2.86e+05, ..., 1.61e+04], lep_eta: [-1.07, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 7.9s
# [{lep_pt: [3.66e+04, ..., 8.26e+03], lep_eta: [-2.04, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.0s
# [{lep_pt: [5.93e+04, ..., 7.27e+03], lep_eta: [1.56, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 8.1s
# [{lep_pt: [6.99e+04, ..., 3.53e+04], lep_eta: [2.17, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.2s
# [{lep_pt: [4.07e+04, ..., 1.3e+04], lep_eta: [1.14, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.3s
# [{lep_pt: [1.02e+05, ..., 2.09e+04], lep_eta: [1.6, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.5s
# [{lep_pt: [1.04e+05, ..., 7.27e+03], lep_eta: [-1.94, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 8.6s
# [{lep_pt: [7.59e+04, ..., 1.06e+04], lep_eta: [-0.0513, ...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 8.7s
# [{lep_pt: [7.45e+04, ..., 2.9e+04], lep_eta: [-1.72, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 8.8s
# [{lep_pt: [1.2e+05, ..., 5.31e+04], lep_eta: [0.786, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 8.9s
# [{lep_pt: [5.29e+04, ..., 7.97e+03], lep_eta: [0.631, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 9.1s
# [{lep_pt: [3e+04, 2.32e+04, ..., 1.03e+04], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 9.2s
# [{lep_pt: [4.65e+04, ..., 9.12e+03], lep_eta: [1.68, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 9.3s
# [{lep_pt: [1.38e+05, ..., 3.01e+04], lep_eta: [-1.2, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 9.4s
# [{lep_pt: [7.13e+04, ..., 1.42e+04], lep_eta: [-0.531, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 9.6s
# [{lep_pt: [2.17e+05, ..., 2.32e+04], lep_eta: [0.138, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 9.7s
# [{lep_pt: [1.27e+05, ..., 1.4e+04], lep_eta: [1.03, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 9.9s
# [{lep_pt: [1.8e+05, ..., 2.22e+04], lep_eta: [0.0919, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 10.0s
# [{lep_pt: [8.11e+04, ..., 1.09e+04], lep_eta: [0.205, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 10.1s
# [{lep_pt: [3.49e+04, ..., 1.44e+04], lep_eta: [-0.387, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 10.2s
# [{lep_pt: [1.84e+05, ..., 2.93e+04], lep_eta: [0.13, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 10.4s
# [{lep_pt: [6.09e+04, ..., 2.29e+04], lep_eta: [0.657, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 10.5s
# [{lep_pt: [6.59e+04, ..., 2.98e+04], lep_eta: [2.07, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 10.6s
# [{lep_pt: [2.71e+04, ..., 1.29e+04], lep_eta: [1.91, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 10.7s
# [{lep_pt: [4.5e+04, ..., 3.28e+04], lep_eta: [0.618, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 11.0s
# [{lep_pt: [5.22e+04, ..., 1.2e+04], lep_eta: [-1.17, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 11.1s
# [{lep_pt: [5.99e+04, ..., 8.04e+03], lep_eta: [0.5, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 11.2s
# [{lep_pt: [5.52e+04, ..., 7.18e+03], lep_eta: [-0.615, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 11.3s
# [{lep_pt: [5.58e+04, ..., 7.25e+03], lep_eta: [-0.388, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 11.4s
# [{lep_pt: [8.03e+04, ..., 1.69e+04], lep_eta: [-0.98, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 11.6s
# [{lep_pt: [3.83e+04, ..., 7.29e+03], lep_eta: [0.14, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 11.7s
# [{lep_pt: [4.88e+04, ..., 8.11e+03], lep_eta: [1.95, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 11.8s
# [{lep_pt: [8.42e+04, ..., 2.7e+04], lep_eta: [-0.541, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 12.0s
# [{lep_pt: [2.88e+04, ..., 7.5e+03], lep_eta: [-1.78, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 12.1s
# [{lep_pt: [5.38e+04, ..., 1.03e+04], lep_eta: [-1.67, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 12.2s
# [{lep_pt: [9.01e+04, ..., 8.16e+03], lep_eta: [-0.0718, ...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 12.3s
# [{lep_pt: [3.91e+04, ..., 9.33e+03], lep_eta: [-0.975, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 12.5s
# [{lep_pt: [8.35e+04, ..., 2.08e+04], lep_eta: [0.484, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 12.6s
# [{lep_pt: [4.74e+04, ..., 3.25e+04], lep_eta: [-2.28, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 12.8s
# [{lep_pt: [7.11e+04, ..., 2.23e+04], lep_eta: [-0.662, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 12.9s
# [{lep_pt: [9.64e+04, ..., 8.14e+03], lep_eta: [0.28, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 13.0s
# [{lep_pt: [3.32e+04, ..., 8.19e+03], lep_eta: [0.215, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 13.1s
# [{lep_pt: [1.16e+05, ..., 4.85e+04], lep_eta: [1.08, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 13.3s
# [{lep_pt: [3.24e+04, ..., 8.8e+03], lep_eta: [1.11, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 13.4s
# [{lep_pt: [2.9e+04, ..., 8.24e+03], lep_eta: [-1.82, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 13.5s
# [{lep_pt: [3.39e+04, ..., 1.36e+04], lep_eta: [1.1, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 13.6s
# [{lep_pt: [5.79e+04, ..., 3.28e+04], lep_eta: [-1.36, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 13.7s
# [{lep_pt: [4.98e+04, ..., 7.03e+03], lep_eta: [0.209, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 13.9s
# [{lep_pt: [4.21e+04, ..., 7.4e+03], lep_eta: [-0.943, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 14.0s
# [{lep_pt: [1.05e+05, ..., 1.44e+04], lep_eta: [-0.845, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 14.1s
# [{lep_pt: [5.03e+04, ..., 2.24e+04], lep_eta: [-0.0467, ...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 14.2s
# [{lep_pt: [6.3e+04, ..., 1.28e+04], lep_eta: [0.75, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 14.3s
# [{lep_pt: [4.6e+04, ..., 9.29e+03], lep_eta: [-1.66, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 14.4s
# [{lep_pt: [3.86e+04, ..., 9.78e+03], lep_eta: [-0.186, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 14.5s
# [{lep_pt: [5.51e+04, ..., 8.5e+03], lep_eta: [-1.63, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 14.6s
# [{lep_pt: [5.83e+04, ..., 1.89e+04], lep_eta: [-1.52, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 14.7s
# [{lep_pt: [4.75e+04, ..., 7.26e+03], lep_eta: [-0.559, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 14.8s
# [{lep_pt: [1.49e+05, ..., 1.16e+04], lep_eta: [-0.0228, ...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 15.0s
# [{lep_pt: [5.94e+04, ..., 8.32e+03], lep_eta: [-0.311, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 15.1s
# [{lep_pt: [6.19e+04, ..., 7.11e+03], lep_eta: [-0.331, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 15.2s
# [{lep_pt: [1.1e+05, ..., 2.67e+04], lep_eta: [-0.161, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 15.3s
# [{lep_pt: [1.07e+05, ..., 8.98e+03], lep_eta: [0.0947, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 15.4s
# [{lep_pt: [1.03e+05, ..., 1.69e+04], lep_eta: [-0.438, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 15.5s
# [{lep_pt: [1.08e+05, ..., 1.68e+04], lep_eta: [-0.524, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 15.6s
# [{lep_pt: [7.6e+04, ..., 9.08e+03], lep_eta: [0.0833, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 15.7s
# [{lep_pt: [1.36e+05, ..., 1.75e+04], lep_eta: [-0.395, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 15.8s
# [{lep_pt: [7.87e+04, ..., 2.48e+04], lep_eta: [2.37, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 15.9s
# [{lep_pt: [6.08e+04, ..., 8.61e+03], lep_eta: [-0.0916, ...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 16.0s
# [{lep_pt: [8.68e+04, ..., 7.21e+03], lep_eta: [-1.87, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 16.1s
# [{lep_pt: [5.77e+04, ..., 2.73e+04], lep_eta: [2.15, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 16.2s
# [{lep_pt: [4.93e+04, 3e+04, ..., 1.29e+04], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 16.3s
# [{lep_pt: [4.04e+04, ..., 8.1e+03], lep_eta: [1.98, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 16.4s
# [{lep_pt: [5.27e+04, ..., 3.57e+04], lep_eta: [1.95, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 16.5s
# [{lep_pt: [1.9e+05, ..., 1.95e+04], lep_eta: [0.531, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 16.7s
# [{lep_pt: [3.71e+04, ..., 7.97e+03], lep_eta: [-2.05, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 16.8s
# [{lep_pt: [4.38e+04, ..., 8.24e+03], lep_eta: [-0.288, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 16.9s
# [{lep_pt: [7.31e+04, ..., 2.97e+04], lep_eta: [0.748, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 17.0s
# [{lep_pt: [6.12e+04, ..., 2.2e+04], lep_eta: [0.0705, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 17.1s
# [{lep_pt: [5.09e+04, ..., 7.95e+03], lep_eta: [-2.24, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 17.3s
# [{lep_pt: [3.6e+04, ..., 7.27e+03], lep_eta: [-2.13, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 17.4s
# [{lep_pt: [6.21e+04, ..., 1.37e+04], lep_eta: [2.04, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 17.5s
# [{lep_pt: [7.48e+04, ..., 1.15e+04], lep_eta: [0.555, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 17.6s
# [{lep_pt: [6.31e+04, ..., 8.96e+03], lep_eta: [-1.65, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 17.7s
# [{lep_pt: [7.26e+04, ..., 1.26e+04], lep_eta: [-0.208, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 17.9s
# [{lep_pt: [3.45e+04, ..., 8.44e+03], lep_eta: [0.253, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 18.0s
# [{lep_pt: [2.17e+05, ..., 9.21e+03], lep_eta: [0.535, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 18.1s
# [{lep_pt: [2.56e+04, ..., 1.06e+04], lep_eta: [1.98, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 18.2s
# [{lep_pt: [2.5e+05, ..., 2.19e+04], lep_eta: [1.25, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 18.3s
# [{lep_pt: [5.86e+04, ..., 7.71e+03], lep_eta: [0.341, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 18.4s
# [{lep_pt: [6.91e+04, ..., 8.67e+03], lep_eta: [-0.854, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 18.5s
# [{lep_pt: [9.89e+04, ..., 1.96e+04], lep_eta: [-0.0858, ...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 18.6s
# [{lep_pt: [3.13e+04, ..., 1.14e+04], lep_eta: [-2.31, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 18.8s
# [{lep_pt: [2.97e+04, ..., 8.42e+03], lep_eta: [-2.35, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 18.9s
# [{lep_pt: [7.39e+04, ..., 9.19e+03], lep_eta: [0.796, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 19.0s
# [{lep_pt: [1e+05, 8.65e+04, ..., 2.54e+04], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 19.1s
# [{lep_pt: [7.26e+04, ..., 3.13e+04], lep_eta: [-1.15, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 19.3s
# [{lep_pt: [5.64e+04, ..., 3.05e+04], lep_eta: [-1.81, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 19.4s
# [{lep_pt: [1.35e+05, ..., 8.92e+03], lep_eta: [-0.272, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 19.5s
# [{lep_pt: [5.87e+04, ..., 8.32e+03], lep_eta: [-2.06, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 19.6s
# [{lep_pt: [4.78e+04, ..., 9.03e+03], lep_eta: [-0.521, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 19.7s
# [{lep_pt: [3.86e+04, ..., 7.4e+03], lep_eta: [1.22, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 19.8s
# [{lep_pt: [6.14e+04, ..., 1.97e+04], lep_eta: [2.01, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 19.9s
# [{lep_pt: [1.1e+05, ..., 8.06e+03], lep_eta: [1.8, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 20.0s
# [{lep_pt: [4.16e+05, ..., 1.18e+04], lep_eta: [...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 20.1s
# [{lep_pt: [2.72e+04, ..., 7.46e+03], lep_eta: [2.34, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 20.2s
# [{lep_pt: [5.87e+04, ..., 1.14e+04], lep_eta: [-0.381, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 20.4s
# [{lep_pt: [4.78e+04, ..., 7.86e+03], lep_eta: [0.474, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 20.5s
# [{lep_pt: [1.4e+06, ..., 1.28e+04], lep_eta: [0.0819, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 20.6s
# [{lep_pt: [1.52e+05, ..., 1.3e+04], lep_eta: [-0.435, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 20.7s
# [{lep_pt: [1.27e+05, ..., 3.75e+04], lep_eta: [2.1, ..., 2], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 20.8s
# [{lep_pt: [6.21e+04, ..., 8.7e+03], lep_eta: [1.07, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 20.9s
# [{lep_pt: [9.55e+04, ..., 1.63e+04], lep_eta: [0.165, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 21.0s
# [{lep_pt: [3.11e+04, ..., 8.83e+03], lep_eta: [1.97, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 21.1s
# [{lep_pt: [7.22e+04, ..., 8.08e+03], lep_eta: [1.76, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 21.2s
# [{lep_pt: [5.55e+04, ..., 1.23e+04], lep_eta: [0.82, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 21.3s
# [{lep_pt: [4.96e+04, ..., 2.97e+04], lep_eta: [-0.296, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 21.4s
# [{lep_pt: [6.3e+04, ..., 1.53e+04], lep_eta: [1.32, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 21.5s
# [{lep_pt: [1.86e+05, ..., 3.96e+04], lep_eta: [-2.07, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 21.6s
# [{lep_pt: [6.02e+04, ..., 7.49e+03], lep_eta: [-0.653, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 21.8s
# [{lep_pt: [4.59e+04, ..., 7.17e+03], lep_eta: [1.18, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 21.9s
# [{lep_pt: [5.26e+04, ..., 7.28e+03], lep_eta: [0.189, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 22.0s
# [{lep_pt: [9.56e+04, ..., 7.3e+03], lep_eta: [0.698, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 22.1s
# [{lep_pt: [2.99e+04, ..., 1.39e+04], lep_eta: [-0.531, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 22.3s
# [{lep_pt: [3.68e+04, ..., 7.71e+03], lep_eta: [-0.086, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 22.4s
# [{lep_pt: [1e+06, 8.24e+04, ..., 1.15e+04], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 22.5s
# [{lep_pt: [1.28e+05, ..., 1.11e+04], lep_eta: [1.06, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 22.6s
# [{lep_pt: [3.82e+04, ..., 7.08e+03], lep_eta: [-0.0121, ...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 22.7s
# [{lep_pt: [5.06e+04, ..., 3.28e+04], lep_eta: [1.4, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 22.8s
# [{lep_pt: [6.5e+04, ..., 7.35e+03], lep_eta: [-0.238, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 22.9s
# [{lep_pt: [1.74e+05, ..., 7.25e+03], lep_eta: [-2.09, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 23.0s
# [{lep_pt: [4.75e+04, ..., 7.12e+03], lep_eta: [1.4, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 23.1s
# [{lep_pt: [4.66e+04, ..., 2.19e+04], lep_eta: [0.471, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 23.3s
# [{lep_pt: [4.51e+04, ..., 9.7e+03], lep_eta: [0.712, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 23.4s
# [{lep_pt: [5.43e+04, ..., 8.54e+03], lep_eta: [1.05, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 23.6s
# [{lep_pt: [1.97e+05, ..., 2.92e+04], lep_eta: [1.06, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 23.7s
# [{lep_pt: [6.87e+04, ..., 1.25e+04], lep_eta: [-0.095, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 23.9s
# s = Background $Z,t\bar{t}$
# Processing Background $Z,t\bar{t}$ samples
# val = Zee
# 	Processing: Zee
# https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/4lep/MC/mc_361106.Zee.4lep.root
# [{lep_pt: [6.38e+04, ..., 7.74e+03], lep_eta: [-0.8, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 0.6s
# [{lep_pt: [4.54e+04, ..., 8.48e+03], lep_eta: [-1.61, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 0.7s
# [{lep_pt: [6.34e+05, ..., 1.13e+04], lep_eta: [0.00903, ...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 0.8s
# [{lep_pt: [3.93e+04, ..., 7.03e+03], lep_eta: [0.872, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 0.9s
# [{lep_pt: [3.49e+04, ..., 1.03e+04], lep_eta: [-0.462, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.1s
# [{lep_pt: [6.39e+04, ..., 8.04e+03], lep_eta: [-1.14, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.2s
# [{lep_pt: [4.51e+04, ..., 7.63e+03], lep_eta: [-1.05, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.4s
# [{lep_pt: [4.66e+04, ..., 7.26e+03], lep_eta: [-0.791, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.5s
# [{lep_pt: [4.37e+04, ..., 7.11e+03], lep_eta: [...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.6s
# [{lep_pt: [4.92e+04, ..., 7.23e+03], lep_eta: [-1.16, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.7s
# [{lep_pt: [4.52e+04, ..., 7.51e+03], lep_eta: [-0.685, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 1.8s
# [{lep_pt: [4.76e+04, ..., 7.16e+03], lep_eta: [-0.809, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# [{lep_pt: [4.3e+04, ..., 7.19e+03], lep_eta: [2.31, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 2.1s
# ...
# 		 nIn: 1,	 nOut: 	1	 in 49.1s
# [{lep_pt: [1.07e+05, ..., 7.88e+03], lep_eta: [0.182, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 49.3s
# [{lep_pt: [5.91e+04, ..., 7.05e+03], lep_eta: [1.1, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 49.4s
# [{lep_pt: [7.35e+04, ..., 8.83e+03], lep_eta: [0.28, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 49.5s
# [{lep_pt: [9.05e+04, ..., 7.79e+03], lep_eta: [-0.697, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 49.6s
# [{lep_pt: [7.28e+04, ..., 8.99e+03], lep_eta: [0.0692, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 49.7s
# [{lep_pt: [9.99e+04, ..., 1.84e+04], lep_eta: [-0.302, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 49.8s
# [{lep_pt: [3.57e+04, ..., 7.23e+03], lep_eta: [...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 50.0s
# [{lep_pt: [5.24e+04, ..., 9.91e+03], lep_eta: [-0.636, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 50.1s
# [{lep_pt: [3.7e+04, ..., 7.19e+03], lep_eta: [-1.89, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 50.2s
# [{lep_pt: [8.1e+04, ..., 7.28e+03], lep_eta: [1.28, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 50.3s
# [{lep_pt: [1.14e+05, ..., 7.29e+03], lep_eta: [0.331, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 50.4s
# [{lep_pt: [7.83e+04, 1.84e+04, ..., 7e+03], lep_eta: [...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 50.5s
# [{lep_pt: [1.23e+05, ..., 8.45e+03], lep_eta: [-0.188, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 50.6s
# [{lep_pt: [3.67e+04, ..., 7.78e+03], lep_eta: [-1.27, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 50.7s
# [{lep_pt: [1.04e+05, ..., 8.91e+03], lep_eta: [-1.22, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 50.9s
# [{lep_pt: [5.81e+04, ..., 7.64e+03], lep_eta: [-1.88, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 51.0s
# [{lep_pt: [4.53e+04, ..., 9.39e+03], lep_eta: [-0.973, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 51.1s
# [{lep_pt: [1.07e+05, ..., 1.35e+04], lep_eta: [2.44, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 51.2s
# [{lep_pt: [5.28e+04, ..., 8.25e+03], lep_eta: [-1.67, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 51.3s
# [{lep_pt: [4.21e+04, ..., 1.34e+04], lep_eta: [1.97, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 51.5s
# [{lep_pt: [1.28e+05, ..., 7.83e+03], lep_eta: [-0.875, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 51.7s
# [{lep_pt: [8.68e+04, ..., 7.61e+03], lep_eta: [-0.231, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 51.8s
# [{lep_pt: [6.96e+04, ..., 8.74e+03], lep_eta: [0.122, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 51.9s
# [{lep_pt: [3.13e+04, ..., 7.09e+03], lep_eta: [-1.91, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 52.1s
# [{lep_pt: [3.76e+04, ..., 1.14e+04], lep_eta: [1.46, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 52.2s
# [{lep_pt: [5.84e+04, ..., 1.78e+04], lep_eta: [-0.0912, ...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 52.3s
# [{lep_pt: [9.07e+04, ..., 7.89e+03], lep_eta: [-2.13, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 52.4s
# [{lep_pt: [2e+05, 1.7e+05, ..., 7.81e+03], lep_eta: [...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 52.5s
# [{lep_pt: [6.2e+04, ..., 7.79e+03], lep_eta: [0.679, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 52.6s
# [{lep_pt: [7.83e+04, ..., 1.08e+04], lep_eta: [-1.6, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 52.7s
# [{lep_pt: [9.83e+04, ..., 7.59e+03], lep_eta: [-1.25, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 52.9s
# [{lep_pt: [1.73e+05, ..., 1.07e+04], lep_eta: [1.67, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 53.0s
# [{lep_pt: [6.91e+04, 6e+04, ..., 7.6e+03], lep_eta: [...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 53.1s
# [{lep_pt: [7.21e+04, ..., 7.91e+03], lep_eta: [0.822, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 53.2s
# [{lep_pt: [4.63e+04, ..., 7.87e+03], lep_eta: [-1.01, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 53.3s
# [{lep_pt: [4.8e+04, ..., 8.74e+03], lep_eta: [0.771, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 53.4s
# [{lep_pt: [5.79e+04, ..., 1.07e+04], lep_eta: [0.599, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 53.5s
# [{lep_pt: [6.18e+04, ..., 7.48e+03], lep_eta: [0.672, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 53.7s
# [{lep_pt: [3.2e+04, ..., 7.38e+03], lep_eta: [-2.38, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 53.8s
# [{lep_pt: [2.93e+04, ..., 1.06e+04], lep_eta: [-0.626, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 53.9s
# [{lep_pt: [9.12e+04, ..., 1.02e+04], lep_eta: [-0.893, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 54.1s
# [{lep_pt: [4.69e+04, ..., 7.25e+03], lep_eta: [-2.2, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 54.2s
# [{lep_pt: [7.61e+04, ..., 9.7e+03], lep_eta: [1.96, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 54.3s
# [{lep_pt: [1.26e+05, ..., 7.26e+03], lep_eta: [1.85, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 54.4s
# [{lep_pt: [1.01e+05, ..., 7.31e+03], lep_eta: [0.0155, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 54.5s
# [{lep_pt: [5.45e+04, ..., 1.57e+04], lep_eta: [-0.228, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 54.6s
# [{lep_pt: [1.33e+05, ..., 1.01e+04], lep_eta: [-1.73, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 54.7s
# [{lep_pt: [1.01e+05, ..., 1.33e+04], lep_eta: [-2.46, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 54.8s
# [{lep_pt: [1.04e+05, ..., 9.27e+03], lep_eta: [-0.118, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 55.0s
# [{lep_pt: [5.64e+04, ..., 8.19e+03], lep_eta: [1.61, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 55.1s
# [{lep_pt: [6.64e+04, ..., 1.07e+04], lep_eta: [-1.11, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 55.2s
# [{lep_pt: [6.69e+04, ..., 9.37e+03], lep_eta: [-1.92, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 55.3s
# [{lep_pt: [1.13e+05, ..., 1.88e+04], lep_eta: [0.89, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 55.4s
# [{lep_pt: [5.14e+04, ..., 7.05e+03], lep_eta: [-0.952, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 55.5s
# [{lep_pt: [6.01e+04, ..., 8.11e+03], lep_eta: [-1.82, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 55.6s
# [{lep_pt: [6.99e+04, ..., 1.05e+04], lep_eta: [-1.13, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 55.7s
# [{lep_pt: [4.4e+04, ..., 7.7e+03], lep_eta: [-0.255, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 55.8s
# [{lep_pt: [9.11e+04, ..., 1.1e+04], lep_eta: [-1.26, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 56.0s
# [{lep_pt: [7.11e+04, ..., 1.36e+04], lep_eta: [0.526, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 56.1s
# [{lep_pt: [4.97e+04, ..., 1.27e+04], lep_eta: [1.72, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 56.2s
# [{lep_pt: [4.92e+04, ..., 1.14e+04], lep_eta: [0.147, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 56.4s
# [{lep_pt: [8.82e+04, ..., 7.59e+03], lep_eta: [-1.31, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 56.5s
# [{lep_pt: [3.45e+04, ..., 9.76e+03], lep_eta: [-1.33, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 56.6s
# [{lep_pt: [8.09e+04, ..., 1.28e+04], lep_eta: [-0.48, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 56.7s
# [{lep_pt: [9.27e+04, ..., 1.31e+04], lep_eta: [0.346, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 56.9s
# [{lep_pt: [4.77e+04, ..., 1.63e+04], lep_eta: [-0.769, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 57.0s
# [{lep_pt: [4.6e+04, ..., 7.48e+03], lep_eta: [0.00075, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 57.1s
# [{lep_pt: [6.05e+04, ..., 7.46e+03], lep_eta: [0.0274, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 57.3s
# [{lep_pt: [3.27e+04, ..., 1.4e+04], lep_eta: [-1.77, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 57.4s
# [{lep_pt: [5.75e+04, ..., 7.99e+03], lep_eta: [0.997, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 57.5s
# [{lep_pt: [2.53e+05, ..., 9.04e+03], lep_eta: [-0.0716, ...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 57.6s
# [{lep_pt: [6.77e+04, ..., 8.74e+03], lep_eta: [-0.635, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 57.7s
# [{lep_pt: [3.05e+04, ..., 8.82e+03], lep_eta: [-0.31, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 57.8s
# [{lep_pt: [7.75e+04, ..., 8.13e+03], lep_eta: [0.471, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 57.9s
# [{lep_pt: [3.55e+04, ..., 7.52e+03], lep_eta: [0.902, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 58.0s
# [{lep_pt: [2.73e+04, ..., 1.2e+04], lep_eta: [1.19, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 58.2s
# [{lep_pt: [5.77e+04, ..., 8.84e+03], lep_eta: [0.637, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 58.3s
# [{lep_pt: [4.33e+04, ..., 9.73e+03], lep_eta: [0.502, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 58.4s
# [{lep_pt: [6.53e+04, ..., 7.77e+03], lep_eta: [0.73, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 58.6s
# [{lep_pt: [1.32e+05, ..., 8.17e+03], lep_eta: [2.08, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 58.7s
# [{lep_pt: [6.45e+04, ..., 8.28e+03], lep_eta: [-1.93, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 58.8s
# [{lep_pt: [7.21e+04, ..., 8.91e+03], lep_eta: [0.456, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 58.9s
# [{lep_pt: [7.63e+04, ..., 7.11e+03], lep_eta: [-0.323, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 59.0s
# [{lep_pt: [7.89e+04, ..., 7.25e+03], lep_eta: [0.652, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 59.1s
# [{lep_pt: [8.31e+04, ..., 7.19e+03], lep_eta: [0.782, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 59.3s
# [{lep_pt: [1.38e+05, ..., 1.21e+04], lep_eta: [0.791, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 59.4s
# [{lep_pt: [4.1e+04, ..., 8.09e+03], lep_eta: [0.499, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 59.6s
# [{lep_pt: [1.14e+05, ..., 1.16e+04], lep_eta: [-0.262, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 59.7s
# [{lep_pt: [7.63e+04, ..., 7.77e+03], lep_eta: [-0.239, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 59.8s
# [{lep_pt: [4.15e+04, ..., 1.1e+04], lep_eta: [-2.4, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 59.9s
# [{lep_pt: [8.61e+04, ..., 1.06e+04], lep_eta: [1.49, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 60.0s
# [{lep_pt: [9.9e+04, ..., 9.95e+03], lep_eta: [0.67, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 60.1s
# [{lep_pt: [7.67e+04, ..., 7.21e+03], lep_eta: [2.03, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 60.2s
# [{lep_pt: [1.54e+05, ..., 1.04e+04], lep_eta: [-0.545, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 60.4s
# [{lep_pt: [3.23e+04, ..., 7.96e+03], lep_eta: [0.858, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 60.5s
# [{lep_pt: [4.02e+04, ..., 1.27e+04], lep_eta: [-1.07, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 60.6s
# [{lep_pt: [9.64e+04, ..., 1.19e+04], lep_eta: [0.0849, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 60.7s
# [{lep_pt: [1.06e+05, ..., 7.32e+03], lep_eta: [-0.533, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 60.8s
# [{lep_pt: [1.37e+05, ..., 8.54e+03], lep_eta: [0.0504, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 61.0s
# [{lep_pt: [1.02e+05, ..., 1.35e+04], lep_eta: [-0.0274, ...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 61.1s
# [{lep_pt: [6.99e+04, ..., 1.34e+04], lep_eta: [1.19, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 61.2s
# [{lep_pt: [1.26e+05, ..., 7.29e+03], lep_eta: [-1.84, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 61.3s
# [{lep_pt: [8.75e+04, ..., 1.08e+04], lep_eta: [-0.885, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 61.4s
# [{lep_pt: [6.13e+04, ..., 1.78e+04], lep_eta: [1.16, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 61.5s
# [{lep_pt: [8.93e+04, ..., 1.02e+04], lep_eta: [0.709, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 61.6s
# [{lep_pt: [8.01e+04, ..., 8.32e+03], lep_eta: [1.81, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 61.7s
# [{lep_pt: [9.88e+04, ..., 8.58e+03], lep_eta: [-0.689, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 61.8s
# [{lep_pt: [7.75e+04, ..., 8.48e+03], lep_eta: [-0.982, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 61.9s
# [{lep_pt: [1.6e+05, 2e+04, ..., 1.02e+04], lep_eta: [...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 62.0s
# [{lep_pt: [5.72e+04, ..., 9.05e+03], lep_eta: [-1.63, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 62.1s
# [{lep_pt: [6.77e+04, ..., 9.02e+03], lep_eta: [-0.65, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 62.2s
# [{lep_pt: [5.93e+04, ..., 8.64e+03], lep_eta: [1.57, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 62.3s
# [{lep_pt: [6.34e+04, ..., 1.25e+04], lep_eta: [-0.64, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 62.4s
# [{lep_pt: [1.15e+05, ..., 7.59e+03], lep_eta: [-0.406, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 62.5s
# [{lep_pt: [8.91e+04, ..., 7.17e+03], lep_eta: [0.698, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 62.6s
# [{lep_pt: [5.08e+04, 2.7e+04, ..., 8e+03], lep_eta: [...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 62.7s
# [{lep_pt: [4.55e+04, ..., 8.7e+03], lep_eta: [1.03, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 62.8s
# [{lep_pt: [5.52e+04, ..., 8.15e+03], lep_eta: [-0.512, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 62.9s
# [{lep_pt: [4.81e+04, ..., 8.39e+03], lep_eta: [-1.59, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 63.0s
# [{lep_pt: [4.95e+04, ..., 9.45e+03], lep_eta: [0.307, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 63.1s
# [{lep_pt: [6.71e+04, ..., 7.23e+03], lep_eta: [-0.429, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 63.3s
# [{lep_pt: [6.34e+04, ..., 1.42e+04], lep_eta: [-1.53, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 63.6s
# [{lep_pt: [8.49e+04, ..., 7.96e+03], lep_eta: [1.63, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	1	 in 63.7s
# [{lep_pt: [9.77e+04, ..., 8.55e+03], lep_eta: [0.0959, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 63.9s
# [{lep_pt: [4.2e+04, ..., 7.17e+03], lep_eta: [2.43, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 64.0s
# [{lep_pt: [6.88e+04, ..., 1.01e+04], lep_eta: [1.95, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 64.1s
# [{lep_pt: [9.93e+04, ..., 1.83e+04], lep_eta: [-1.31, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 64.3s
# [{lep_pt: [8.87e+04, ..., 7.67e+03], lep_eta: [1.9, ...], lep_phi: [...], ...}]
# 		 nIn: 1,	 nOut: 	0	 in 64.4s
# [{lep_pt: [4.33e+04, ..., 1.12e+04], lep_eta: [0.877, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	0	 in 64.5s
# [{lep_pt: [4.16e+04, ..., 7.25e+03], lep_eta: [-1.04, ...], lep_phi: ..., ...}]
# 		 nIn: 1,	 nOut: 	1	 in 64.6s
# s = Background $ZZ^*$
# Processing Background $ZZ^*$ samples
# val = llll
# 	Processing: llll
# https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/4lep/MC/mc_363490.llll.4lep.root
# [{lep_pt: [6.49e+04, ..., 4.44e+04], lep_eta: [1.51, ...], ...}, ..., {...}]
# 		 nIn: 277139,	 nOut: 	261841	 in 6.9s
# s = Signal ($m_H$ = 125 GeV)
# Processing Signal ($m_H$ = 125 GeV) samples
# val = ggH125_ZZ4lep
# 	Processing: ggH125_ZZ4lep
# https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/4lep/MC/mc_345060.ggH125_ZZ4lep.4lep.root
# [{lep_pt: [5.19e+04, ..., 7.47e+03], lep_eta: [...], lep_phi: [...], ...}, ...]
# 		 nIn: 82358,	 nOut: 	80729	 in 10.9s
# val = VBFH125_ZZ4lep
# 	Processing: VBFH125_ZZ4lep
# https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/4lep/MC/mc_344235.VBFH125_ZZ4lep.4lep.root
# [{lep_pt: [9.81e+04, ..., 8.46e+03], lep_eta: [...], lep_phi: [...], ...}, ...]
# 		 nIn: 95563,	 nOut: 	93473	 in 10.3s
# val = WH125_ZZ4lep
# 	Processing: WH125_ZZ4lep
# https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/4lep/MC/mc_341964.WH125_ZZ4lep.4lep.root
# [{lep_pt: [8.09e+04, ..., 1.36e+04], lep_eta: [1.16, ...], ...}, ..., {...}]
# 		 nIn: 7689,	 nOut: 	4863	 in 3.4s
# val = ZH125_ZZ4lep
# 	Processing: ZH125_ZZ4lep
# https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/4lep/MC/mc_341947.ZH125_ZZ4lep.4lep.root
# [{lep_pt: [6.39e+04, ..., 1.36e+04], lep_eta: [...], lep_phi: [...], ...}, ...]
# 		 nIn: 7242,	 nOut: 	5996	 in 1.9s
# Time taken: 257.2s

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# <a id='plotting'></a>

# %% [markdown]
# ## Plotting
# If you only want to make a change in plotting: Cell -> Run All Below
#
# Define function to plot the data

# %%
def plot_data(data):

    xmin = 80 * GeV
    xmax = 250 * GeV
    step_size = 5 * GeV

    bin_edges = np.arange(start=xmin, # The interval includes this value
                     stop=xmax+step_size, # The interval doesn't include this value
                     step=step_size ) # Spacing between values
    bin_centres = np.arange(start=xmin+step_size/2, # The interval includes this value
                            stop=xmax+step_size/2, # The interval doesn't include this value
                            step=step_size ) # Spacing between values

    data_x,_ = np.histogram(ak.to_numpy(data['data']['mllll']), 
                            bins=bin_edges ) # histogram the data
    data_x_errors = np.sqrt( data_x ) # statistical error on the data

    signal_x = ak.to_numpy(data[r'Signal ($m_H$ = 125 GeV)']['mllll']) # histogram the signal
    signal_weights = ak.to_numpy(data[r'Signal ($m_H$ = 125 GeV)'].totalWeight) # get the weights of the signal events
    signal_color = samples[r'Signal ($m_H$ = 125 GeV)']['color'] # get the colour for the signal bar

    mc_x = [] # define list to hold the Monte Carlo histogram entries
    mc_weights = [] # define list to hold the Monte Carlo weights
    mc_colors = [] # define list to hold the colors of the Monte Carlo bars
    mc_labels = [] # define list to hold the legend labels of the Monte Carlo bars

    for s in samples: # loop over samples
        if s not in ['data', r'Signal ($m_H$ = 125 GeV)']: # if not data nor signal
            mc_x.append( ak.to_numpy(data[s]['mllll']) ) # append to the list of Monte Carlo histogram entries
            mc_weights.append( ak.to_numpy(data[s].totalWeight) ) # append to the list of Monte Carlo weights
            mc_colors.append( samples[s]['color'] ) # append to the list of Monte Carlo bar colors
            mc_labels.append( s ) # append to the list of Monte Carlo legend labels
    


    # *************
    # Main plot 
    # *************
    main_axes = plt.gca() # get current axes
    
    # plot the data points
    main_axes.errorbar(x=bin_centres, y=data_x, yerr=data_x_errors,
                       fmt='ko', # 'k' means black and 'o' is for circles 
                       label='Data') 
    
    # plot the Monte Carlo bars
    mc_heights = main_axes.hist(mc_x, bins=bin_edges, 
                                weights=mc_weights, stacked=True, 
                                color=mc_colors, label=mc_labels )
    
    mc_x_tot = mc_heights[0][-1] # stacked background MC y-axis value
    
    # calculate MC statistical uncertainty: sqrt(sum w^2)
    mc_x_err = np.sqrt(np.histogram(np.hstack(mc_x), bins=bin_edges, weights=np.hstack(mc_weights)**2)[0])
    
    # plot the signal bar
    main_axes.hist(signal_x, bins=bin_edges, bottom=mc_x_tot, 
                   weights=signal_weights, color=signal_color,
                   label=r'Signal ($m_H$ = 125 GeV)')
    
    # plot the statistical uncertainty
    main_axes.bar(bin_centres, # x
                  2*mc_x_err, # heights
                  alpha=0.5, # half transparency
                  bottom=mc_x_tot-mc_x_err, color='none', 
                  hatch="////", width=step_size, label='Stat. Unc.' )

    # set the x-limit of the main axes
    main_axes.set_xlim( left=xmin, right=xmax ) 
    
    # separation of x axis minor ticks
    main_axes.xaxis.set_minor_locator( AutoMinorLocator() ) 
    
    # set the axis tick parameters for the main axes
    main_axes.tick_params(which='both', # ticks on both x and y axes
                          direction='in', # Put ticks inside and outside the axes
                          top=True, # draw ticks on the top axis
                          right=True ) # draw ticks on right axis
    
    # x-axis label
    main_axes.set_xlabel(r'4-lepton invariant mass $\mathrm{m_{4l}}$ [GeV]',
                        fontsize=13, x=1, horizontalalignment='right' )
    
    # write y-axis label for main axes
    main_axes.set_ylabel('Events / '+str(step_size)+' GeV',
                         y=1, horizontalalignment='right') 
    
    # set y-axis limits for main axes
    main_axes.set_ylim( bottom=0, top=np.amax(data_x)*1.6 )
    
    # add minor ticks on y-axis for main axes
    main_axes.yaxis.set_minor_locator( AutoMinorLocator() ) 

    # Add text 'ATLAS Open Data' on plot
    plt.text(0.05, # x
             0.93, # y
             'ATLAS Open Data', # text
             transform=main_axes.transAxes, # coordinate system used is that of main_axes
             fontsize=13 ) 
    
    # Add text 'for education' on plot
    plt.text(0.05, # x
             0.88, # y
             'for education', # text
             transform=main_axes.transAxes, # coordinate system used is that of main_axes
             style='italic',
             fontsize=8 ) 
    
    # Add energy and luminosity
    lumi_used = str(lumi*fraction) # luminosity to write on the plot
    plt.text(0.05, # x
             0.82, # y
             '$\sqrt{s}$=13 TeV,$\int$L dt = '+lumi_used+' fb$^{-1}$', # text
             transform=main_axes.transAxes ) # coordinate system used is that of main_axes
    
    # Add a label for the analysis carried out
    plt.text(0.05, # x
             0.76, # y
             r'$H \rightarrow ZZ^* \rightarrow 4\ell$', # text 
             transform=main_axes.transAxes ) # coordinate system used is that of main_axes

    # draw the legend
    main_axes.legend( frameon=False ) # no box around the legend
    
    return

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# Call the function to plot the data

# %%
plot_data(data)

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# <a id='going_further'></a>

# %% [markdown]
# ## What can you do to explore this analysis?
#
# * Increase the fraction of data used in '[Lumi, fraction, file path](#fraction)'
# * Check how many events are being thrown away by each cut in '[Applying a cut](#applying_cut)'
# * Add more cuts from the [Higgs discovery paper](https://www.sciencedirect.com/science/article/pii/S037026931200857X#se0040) in '[Changing a cut](#changing_cut)' and '[Applying a cut](#applying_cut)'
# * Add a plot to show the ratio between Data and MC other than Higgs
# * Add a plot to show the invariant mass distribution of the sub-leading lepton pair, like [Figure 1 of the Higgs discovery paper](https://www.sciencedirect.com/science/article/pii/S037026931200857X#fg0010)
# * Get the estimated numbers of events, like [Table 3 of the Higgs discovery paper](https://www.sciencedirect.com/science/article/pii/S037026931200857X#tl0030)
# * Add a plot of m12 against m34, like [Figure 3 of the Higgs discovery paper](https://www.sciencedirect.com/science/article/pii/S037026931200857X#fg0030)
# * Your idea!

# %% [markdown]
# [Back to contents](#contents)
